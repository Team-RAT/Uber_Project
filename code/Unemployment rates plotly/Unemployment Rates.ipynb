# %%
import pyodbc
import pymongo
import pprint
from pandas import DataFrame
import itertools
import pandas as pd

# %%
c = pyodbc.connect('DSN=sqluberconn;UID=tabi;PWD=password')

# %%
pd.read_sql_query(sql = r'select [UALAD], [2011], [2012], [2013], [2014], [2015], [2016] from unemployment.[Rates_perc]', con = c)
# Out:
#                          UALAD  2011  2012  2013 2014 2015 2016
# 0                    Allerdale   7.6   7.1   6.6  5.6  3.9  4.0
# 1            Barrow-in-Furness   9.6   9.1   7.9  7.4  6.3  5.6
# 2                     Carlisle   6.2   5.7   6.0  4.9  2.8  4.5
# 3                     Copeland   8.2   7.6   6.5  6.0  5.3  5.5
# 4                         Eden   3.8   3.1   2.7  2.8  1.8  2.5
# 5               South Lakeland   3.6   3.3   2.5  3.1  2.1  2.4
# 6                County Durham   8.8   9.9   9.1  7.6  6.8  5.9
# 7               Northumberland   7.8   7.7   7.1  6.7  6.2  5.5
# 8                       Craven   6.4   5.1   4.7  3.5  3.1  3.2
# 9                    Hambleton   5.1   4.5   4.1  3.3  2.8  2.8
# 10                   Harrogate   5.6   4.5   3.3  3.0  2.7  2.7
# 11               Richmondshire   5.9   5.3   4.2  3.2  2.4  2.8
# 12                     Ryedale   5.0   5.0   4.1  3.4  2.9  3.3
# 13                 Scarborough   7.7   8.7   8.7  7.3  3.4  3.7
# ...
